# %%
import spacy

# %%
# load in the english model
nlp = spacy.load('en_core_web_lg')
doc = nlp('Hello    World!')
for token in doc:
    print('"' + token.text + '"')
# Out:
# "Hello"
# "   "
# "World"
# "!"

# %%
# Maintain token's position in text
doc
for token in doc:
    print('"' + token.text + '"', token.idx)
# Out:
# "Hello" 0
# "   " 6
# "World" 9
# "!" 14

# %%
doc = nlp("""
You know what to say on my way out
Hit me with the "Hey, been a while"
Now I'm going straight through the fire, fire
(I don't even know why though)
Get me on a wave then you fade out
Hit me with the light, got me tired
I should get away from you, I know, I know
(I don't even know why though)
High hopes, I fall for the cycle
High low, I'm on on a spiral
Love me, wide open then leave me
I don't (I don't even know why though)
I just want to put my weight on you
Switch it, smoke it, I'mma sway on you
Know I shouldn't, I'mma wait on you
I don't even know why though
I just want to put my weight on you
Switch it, smoke it, I'mma sway on you
Know I shouldn't, I'mma wait on you
I don't even know why though
I don't even know why though
Maybe it's the love that you show me
Make my body feel like it's holy
(Feel too good to say you hurt too much, too late)
You're just what I need (I don't even know why though)
High hopes, I fall for the cycle
High low, I'm on on a spiral
Love me, wide open then leave me
I don't (I don't even know why though)
I just want to put my weight on you
Switch it, smoke it, I'mma sway on you
Know I shouldn't, I'mma wait on you
I don't even know why though
I just want to put my weight on you
Switch it, smoke it, I'mma sway on you
Know I shouldn't, I'mma wait on you
I don't even know why though
I don't even know why though
I just want to put my weight on you
Switch it, smoke it, I'mma sway on you
Know I shouldn't, I'mma wait on you
I don't even know why though
I just want to put my weight on you
Switch it, smoke it, I'mma sway on you
Know I shouldn't, I'mma wait on you
I don't even know why though
I don't even know why though
""")
for token in doc:
    print("{0}\t{1}\t{2}\t{3}\t{4}\t{5}\t{6}\t{7}".format(
        token.text,
        token.idx,
        token.lemma_,
        token.is_punct,
        token.is_space,
        token.shape_,
        token.pos_,
        token.rank))
# Out:
# 	0
# 	False	True
# 	SPACE	0
# You	1	-PRON-	False	False	Xxx	PRON	73
# know	5	know	False	False	xxxx	VERB	78
# what	10	what	False	False	xxxx	PRON	59
# to	15	to	False	False	xx	PART	5
# say	18	say	False	False	xxx	VERB	129
# on	22	on	False	False	xx	ADP	20
# my	25	-PRON-	False	False	xx	DET	34
# way	28	way	False	False	xxx	NOUN	110
# out	32	out	False	False	xxx	ADV	56
#
# 	35
# 	False	True
# 	SPACE	0
# Hit	36	hit	False	False	Xxx	VERB	6562
# me	40	-PRON-	False	False	xx	PRON	47
# with	43	with	False	False	xxxx	ADP	24
# the	48	the	False	False	xxx	DET	3
# "	52	"	True	False	"	PUNCT	17
# Hey	53	hey	False	False	Xxx	INTJ	738
# ,	56	,	True	False	,	PUNCT	2
# been	58	be	False	False	xxxx	VERB	101
# a	63	a	False	False	x	DET	6
# while	65	while	False	False	xxxx	NOUN	195
# "	70	"	True	False	"	PUNCT	17
#
# 	71
# 	False	True
# 	SPACE	0
# Now	72	now	False	False	Xxx	ADV	410
# I	76	-PRON-	False	False	X	PRON	4
# 'm	77	be	False	False	'x	VERB	55
# going	80	go	False	False	xxxx	VERB	117
# straight	86	straight	False	False	xxxx	ADV	764
# through	95	through	False	False	xxxx	ADP	214
# the	103	the	False	False	xxx	DET	3
# fire	107	fire	False	False	xxxx	NOUN	820
# ,	111	,	True	False	,	PUNCT	2
# fire	113	fire	False	False	xxxx	NOUN	820
#
# 	117
# 	False	True
# 	SPACE	0
# (	118	(	True	False	(	PUNCT	41
# I	119	-PRON-	False	False	X	PRON	4
# do	121	do	False	False	xx	VERB	25
# n't	123	not	False	False	x'x	ADV	15
# even	127	even	False	False	xxxx	ADV	108
# know	132	know	False	False	xxxx	VERB	78
# why	137	why	False	False	xxx	ADV	161
# though	141	though	False	False	xxxx	ADV	151
# )	147	)	True	False	)	PUNCT	22
#
# 	148
# 	False	True
# 	SPACE	0
# Get	149	Get	False	False	Xxx	VERB	941
# me	153	-PRON-	False	False	xx	PRON	47
# on	156	on	False	False	xx	ADP	20
# a	159	a	False	False	x	DET	6
# wave	161	wave	False	False	xxxx	NOUN	2856
# then	166	then	False	False	xxxx	ADV	98
# you	171	-PRON-	False	False	xxx	PRON	9
# fade	175	fade	False	False	xxxx	VERB	6984
# out	180	out	False	False	xxx	PART	56
#
# 	183
# 	False	True
# 	SPACE	0
# Hit	184	hit	False	False	Xxx	VERB	6562
# me	188	-PRON-	False	False	xx	PRON	47
# with	191	with	False	False	xxxx	ADP	24
# the	196	the	False	False	xxx	DET	3
# light	200	light	False	False	xxxx	NOUN	649
# ,	205	,	True	False	,	PUNCT	2
# got	207	get	False	False	xxx	VERB	131
# me	211	-PRON-	False	False	xx	PRON	47
# tired	214	tired	False	False	xxxx	ADJ	1695
#
# 	219
# 	False	True
# 	SPACE	0
# I	220	-PRON-	False	False	X	PRON	4
# should	222	should	False	False	xxxx	VERB	109
# get	229	get	False	False	xxx	VERB	53
# away	233	away	False	False	xxxx	ADV	282
# from	238	from	False	False	xxxx	ADP	57
# you	243	-PRON-	False	False	xxx	PRON	9
# ,	246	,	True	False	,	PUNCT	2
# I	248	-PRON-	False	False	X	PRON	4
# know	250	know	False	False	xxxx	VERB	78
# ,	254	,	True	False	,	PUNCT	2
# I	256	-PRON-	False	False	X	PRON	4
# know	258	know	False	False	xxxx	VERB	78
#
# 	262
# 	False	True
# 	SPACE	0
# (	263	(	True	False	(	PUNCT	41
# I	264	-PRON-	False	False	X	PRON	4
# do	266	do	False	False	xx	VERB	25
# n't	268	not	False	False	x'x	ADV	15
# even	272	even	False	False	xxxx	ADV	108
# know	277	know	False	False	xxxx	VERB	78
# why	282	why	False	False	xxx	ADV	161
# though	286	though	False	False	xxxx	ADV	151
# )	292	)	True	False	)	PUNCT	22
#
# 	293
# 	False	True
# 	SPACE	0
# High	294	high	False	False	Xxxx	ADJ	2508
# hopes	299	hope	False	False	xxxx	NOUN	3950
# ,	304	,	True	False	,	PUNCT	2
# I	306	-PRON-	False	False	X	PRON	4
# fall	308	fall	False	False	xxxx	VERB	1004
# for	313	for	False	False	xxx	ADP	16
# the	317	the	False	False	xxx	DET	3
# cycle	321	cycle	False	False	xxxx	NOUN	2570
#
# 	326
# 	False	True
# 	SPACE	0
# High	327	high	False	False	Xxxx	ADJ	2508
# low	332	low	False	False	xxx	NOUN	535
# ,	335	,	True	False	,	PUNCT	2
# I	337	-PRON-	False	False	X	PRON	4
# 'm	338	be	False	False	'x	VERB	55
# on	341	on	False	False	xx	PART	20
# on	344	on	False	False	xx	ADP	20
# a	347	a	False	False	x	DET	6
# spiral	349	spiral	False	False	xxxx	ADJ	10796
#
# 	355
# 	False	True
# 	SPACE	0
# Love	356	love	False	False	Xxxx	VERB	1367
# me	361	-PRON-	False	False	xx	PRON	47
# ,	363	,	True	False	,	PUNCT	2
# wide	365	wide	False	False	xxxx	ADV	1944
# open	370	open	False	False	xxxx	ADJ	463
# then	375	then	False	False	xxxx	ADV	98
# leave	380	leave	False	False	xxxx	VERB	523
# me	386	-PRON-	False	False	xx	PRON	47
#
# 	388
# 	False	True
# 	SPACE	0
# I	389	-PRON-	False	False	X	PRON	4
# do	391	do	False	False	xx	VERB	25
# n't	393	not	False	False	x'x	ADV	15
# (	397	(	True	False	(	PUNCT	41
# I	398	-PRON-	False	False	X	PRON	4
# do	400	do	False	False	xx	VERB	25
# n't	402	not	False	False	x'x	ADV	15
# even	406	even	False	False	xxxx	ADV	108
# know	411	know	False	False	xxxx	VERB	78
# why	416	why	False	False	xxx	ADV	161
# though	420	though	False	False	xxxx	ADV	151
# )	426	)	True	False	)	PUNCT	22
#
# 	427
# 	False	True
# 	SPACE	0
# I	428	-PRON-	False	False	X	PRON	4
# just	430	just	False	False	xxxx	ADV	38
# want	435	want	False	False	xxxx	VERB	107
# to	440	to	False	False	xx	PART	5
# put	443	put	False	False	xxx	VERB	232
# my	447	-PRON-	False	False	xx	DET	34
# weight	450	weight	False	False	xxxx	NOUN	773
# on	457	on	False	False	xx	ADP	20
# you	460	-PRON-	False	False	xxx	PRON	9
#
# 	463
# 	False	True
# 	SPACE	0
# Switch	464	switch	False	False	Xxxxx	VERB	14367
# it	471	-PRON-	False	False	xx	PRON	10
# ,	473	,	True	False	,	PUNCT	2
# smoke	475	smoke	False	False	xxxx	VERB	1306
# it	481	-PRON-	False	False	xx	PRON	10
# ,	483	,	True	False	,	PUNCT	2
# I'mma	485	I'mma	False	False	X'xxx	PROPN	0
# sway	491	sway	False	False	xxxx	VERB	10992
# on	496	on	False	False	xx	ADP	20
# you	499	-PRON-	False	False	xxx	PRON	9
#
# 	502
# 	False	True
# 	SPACE	0
# Know	503	know	False	False	Xxxx	VERB	6618
# I	508	-PRON-	False	False	X	PRON	4
# should	510	should	False	False	xxxx	AUX	109
# n't	516	not	False	False	x'x	ADV	15
# ,	519	,	True	False	,	PUNCT	2
# I'mma	521	I'mma	False	False	X'xxx	PROPN	0
# wait	527	wait	False	False	xxxx	VERB	485
# on	532	on	False	False	xx	ADP	20
# you	535	-PRON-	False	False	xxx	PRON	9
#
# 	538
# 	False	True
# 	SPACE	0
# I	539	-PRON-	False	False	X	PRON	4
# do	541	do	False	False	xx	VERB	25
# n't	543	not	False	False	x'x	ADV	15
# even	547	even	False	False	xxxx	ADV	108
# know	552	know	False	False	xxxx	VERB	78
# why	557	why	False	False	xxx	ADV	161
# though	561	though	False	False	xxxx	ADV	151
#
# 	567
# 	False	True
# 	SPACE	0
# I	568	-PRON-	False	False	X	PRON	4
# just	570	just	False	False	xxxx	ADV	38
# want	575	want	False	False	xxxx	VERB	107
# to	580	to	False	False	xx	PART	5
# put	583	put	False	False	xxx	VERB	232
# my	587	-PRON-	False	False	xx	DET	34
# weight	590	weight	False	False	xxxx	NOUN	773
# on	597	on	False	False	xx	ADP	20
# you	600	-PRON-	False	False	xxx	PRON	9
#
# 	603
# 	False	True
# 	SPACE	0
# Switch	604	switch	False	False	Xxxxx	VERB	14367
# it	611	-PRON-	False	False	xx	PRON	10
# ,	613	,	True	False	,	PUNCT	2
# smoke	615	smoke	False	False	xxxx	VERB	1306
# it	621	-PRON-	False	False	xx	PRON	10
# ,	623	,	True	False	,	PUNCT	2
# I'mma	625	I'mma	False	False	X'xxx	PROPN	0
# sway	631	sway	False	False	xxxx	VERB	10992
# on	636	on	False	False	xx	ADP	20
# you	639	-PRON-	False	False	xxx	PRON	9
#
# 	642
# 	False	True
# 	SPACE	0
# Know	643	know	False	False	Xxxx	VERB	6618
# I	648	-PRON-	False	False	X	PRON	4
# should	650	should	False	False	xxxx	AUX	109
# n't	656	not	False	False	x'x	ADV	15
# ,	659	,	True	False	,	PUNCT	2
# I'mma	661	I'mma	False	False	X'xxx	PROPN	0
# wait	667	wait	False	False	xxxx	VERB	485
# on	672	on	False	False	xx	ADP	20
# you	675	-PRON-	False	False	xxx	PRON	9
#
# 	678
# 	False	True
# 	SPACE	0
# I	679	-PRON-	False	False	X	PRON	4
# do	681	do	False	False	xx	VERB	25
# n't	683	not	False	False	x'x	ADV	15
# even	687	even	False	False	xxxx	ADV	108
# know	692	know	False	False	xxxx	VERB	78
# why	697	why	False	False	xxx	ADV	161
# though	701	though	False	False	xxxx	ADV	151
#
# 	707
# 	False	True
# 	SPACE	0
# I	708	-PRON-	False	False	X	PRON	4
# do	710	do	False	False	xx	VERB	25
# n't	712	not	False	False	x'x	ADV	15
# even	716	even	False	False	xxxx	ADV	108
# know	721	know	False	False	xxxx	VERB	78
# why	726	why	False	False	xxx	ADV	161
# though	730	though	False	False	xxxx	ADP	151
#
# 	736
# 	False	True
# 	SPACE	0
# Maybe	737	maybe	False	False	Xxxxx	ADV	393
# it	743	-PRON-	False	False	xx	PRON	10
# 's	745	be	False	False	'x	VERB	14
# the	748	the	False	False	xxx	DET	3
# love	752	love	False	False	xxxx	NOUN	179
# that	757	that	False	False	xxxx	DET	12
# you	762	-PRON-	False	False	xxx	PRON	9
# show	766	show	False	False	xxxx	VERB	309
# me	771	-PRON-	False	False	xx	PRON	47
#
# 	773
# 	False	True
# 	SPACE	0
# Make	774	make	False	False	Xxxx	VERB	1450
# my	779	-PRON-	False	False	xx	DET	34
# body	782	body	False	False	xxxx	NOUN	501
# feel	787	feel	False	False	xxxx	VERB	173
# like	792	like	False	False	xxxx	ADP	37
# it	797	-PRON-	False	False	xx	PRON	10
# 's	799	be	False	False	'x	VERB	14
# holy	802	holy	False	False	xxxx	ADJ	2391
#
# 	806
# 	False	True
# 	SPACE	0
# (	807	(	True	False	(	PUNCT	41
# Feel	808	feel	False	False	Xxxx	VERB	3832
# too	813	too	False	False	xxx	ADV	112
# good	817	good	False	False	xxxx	ADJ	91
# to	822	to	False	False	xx	PART	5
# say	825	say	False	False	xxx	VERB	129
# you	829	-PRON-	False	False	xxx	PRON	9
# hurt	833	hurt	False	False	xxxx	VERB	902
# too	838	too	False	False	xxx	ADV	112
# much	842	much	False	False	xxxx	ADV	94
# ,	846	,	True	False	,	PUNCT	2
# too	848	too	False	False	xxx	ADV	112
# late	852	late	False	False	xxxx	ADV	769
# )	856	)	True	False	)	PUNCT	22
#
# 	857
# 	False	True
# 	SPACE	0
# You	858	-PRON-	False	False	Xxx	PRON	73
# 're	861	be	False	False	'xx	VERB	71
# just	865	just	False	False	xxxx	ADV	38
# what	870	what	False	False	xxxx	PRON	59
# I	875	-PRON-	False	False	X	PRON	4
# need	877	need	False	False	xxxx	VERB	133
# (	882	(	True	False	(	PUNCT	41
# I	883	-PRON-	False	False	X	PRON	4
# do	885	do	False	False	xx	VERB	25
# n't	887	not	False	False	x'x	ADV	15
# even	891	even	False	False	xxxx	ADV	108
# know	896	know	False	False	xxxx	VERB	78
# why	901	why	False	False	xxx	ADV	161
# though	905	though	False	False	xxxx	ADV	151
# )	911	)	True	False	)	PUNCT	22
#
# 	912
# 	False	True
# 	SPACE	0
# High	913	high	False	False	Xxxx	ADJ	2508
# hopes	918	hope	False	False	xxxx	NOUN	3950
# ,	923	,	True	False	,	PUNCT	2
# I	925	-PRON-	False	False	X	PRON	4
# fall	927	fall	False	False	xxxx	VERB	1004
# for	932	for	False	False	xxx	ADP	16
# the	936	the	False	False	xxx	DET	3
# cycle	940	cycle	False	False	xxxx	NOUN	2570
#
# 	945
# 	False	True
# 	SPACE	0
# High	946	high	False	False	Xxxx	ADJ	2508
# low	951	low	False	False	xxx	NOUN	535
# ,	954	,	True	False	,	PUNCT	2
# I	956	-PRON-	False	False	X	PRON	4
# 'm	957	be	False	False	'x	VERB	55
# on	960	on	False	False	xx	PART	20
# on	963	on	False	False	xx	ADP	20
# a	966	a	False	False	x	DET	6
# spiral	968	spiral	False	False	xxxx	ADJ	10796
#
# 	974
# 	False	True
# 	SPACE	0
# Love	975	love	False	False	Xxxx	VERB	1367
# me	980	-PRON-	False	False	xx	PRON	47
# ,	982	,	True	False	,	PUNCT	2
# wide	984	wide	False	False	xxxx	ADV	1944
# open	989	open	False	False	xxxx	ADJ	463
# then	994	then	False	False	xxxx	ADV	98
# leave	999	leave	False	False	xxxx	VERB	523
# me	1005	-PRON-	False	False	xx	PRON	47
#
# 	1007
# 	False	True
# 	SPACE	0
# I	1008	-PRON-	False	False	X	PRON	4
# do	1010	do	False	False	xx	VERB	25
# n't	1012	not	False	False	x'x	ADV	15
# (	1016	(	True	False	(	PUNCT	41
# I	1017	-PRON-	False	False	X	PRON	4
# do	1019	do	False	False	xx	VERB	25
# n't	1021	not	False	False	x'x	ADV	15
# even	1025	even	False	False	xxxx	ADV	108
# know	1030	know	False	False	xxxx	VERB	78
# why	1035	why	False	False	xxx	ADV	161
# though	1039	though	False	False	xxxx	ADV	151
# )	1045	)	True	False	)	PUNCT	22
#
# 	1046
# 	False	True
# 	SPACE	0
# I	1047	-PRON-	False	False	X	PRON	4
# just	1049	just	False	False	xxxx	ADV	38
# want	1054	want	False	False	xxxx	VERB	107
# to	1059	to	False	False	xx	PART	5
# put	1062	put	False	False	xxx	VERB	232
# my	1066	-PRON-	False	False	xx	DET	34
# weight	1069	weight	False	False	xxxx	NOUN	773
# on	1076	on	False	False	xx	ADP	20
# you	1079	-PRON-	False	False	xxx	PRON	9
#
# 	1082
# 	False	True
# 	SPACE	0
# Switch	1083	switch	False	False	Xxxxx	VERB	14367
# it	1090	-PRON-	False	False	xx	PRON	10
# ,	1092	,	True	False	,	PUNCT	2
# smoke	1094	smoke	False	False	xxxx	VERB	1306
# it	1100	-PRON-	False	False	xx	PRON	10
# ,	1102	,	True	False	,	PUNCT	2
# I'mma	1104	I'mma	False	False	X'xxx	PROPN	0
# sway	1110	sway	False	False	xxxx	VERB	10992
# on	1115	on	False	False	xx	ADP	20
# you	1118	-PRON-	False	False	xxx	PRON	9
#
# 	1121
# 	False	True
# 	SPACE	0
# Know	1122	know	False	False	Xxxx	VERB	6618
# I	1127	-PRON-	False	False	X	PRON	4
# should	1129	should	False	False	xxxx	AUX	109
# n't	1135	not	False	False	x'x	ADV	15
# ,	1138	,	True	False	,	PUNCT	2
# I'mma	1140	I'mma	False	False	X'xxx	PROPN	0
# wait	1146	wait	False	False	xxxx	VERB	485
# on	1151	on	False	False	xx	ADP	20
# you	1154	-PRON-	False	False	xxx	PRON	9
#
# 	1157
# 	False	True
# 	SPACE	0
# I	1158	-PRON-	False	False	X	PRON	4
# do	1160	do	False	False	xx	VERB	25
# n't	1162	not	False	False	x'x	ADV	15
# even	1166	even	False	False	xxxx	ADV	108
# know	1171	know	False	False	xxxx	VERB	78
# why	1176	why	False	False	xxx	ADV	161
# though	1180	though	False	False	xxxx	ADV	151
#
# 	1186
# 	False	True
# 	SPACE	0
# I	1187	-PRON-	False	False	X	PRON	4
# just	1189	just	False	False	xxxx	ADV	38
# want	1194	want	False	False	xxxx	VERB	107
# to	1199	to	False	False	xx	PART	5
# put	1202	put	False	False	xxx	VERB	232
# my	1206	-PRON-	False	False	xx	DET	34
# weight	1209	weight	False	False	xxxx	NOUN	773
# on	1216	on	False	False	xx	ADP	20
# you	1219	-PRON-	False	False	xxx	PRON	9
#
# 	1222
# 	False	True
# 	SPACE	0
# Switch	1223	switch	False	False	Xxxxx	VERB	14367
# it	1230	-PRON-	False	False	xx	PRON	10
# ,	1232	,	True	False	,	PUNCT	2
# smoke	1234	smoke	False	False	xxxx	VERB	1306
# it	1240	-PRON-	False	False	xx	PRON	10
# ,	1242	,	True	False	,	PUNCT	2
# I'mma	1244	I'mma	False	False	X'xxx	PROPN	0
# sway	1250	sway	False	False	xxxx	VERB	10992
# on	1255	on	False	False	xx	ADP	20
# you	1258	-PRON-	False	False	xxx	PRON	9
#
# 	1261
# 	False	True
# 	SPACE	0
# Know	1262	know	False	False	Xxxx	VERB	6618
# I	1267	-PRON-	False	False	X	PRON	4
# should	1269	should	False	False	xxxx	AUX	109
# n't	1275	not	False	False	x'x	ADV	15
# ,	1278	,	True	False	,	PUNCT	2
# I'mma	1280	I'mma	False	False	X'xxx	PROPN	0
# wait	1286	wait	False	False	xxxx	VERB	485
# on	1291	on	False	False	xx	ADP	20
# you	1294	-PRON-	False	False	xxx	PRON	9
#
# 	1297
# 	False	True
# 	SPACE	0
# I	1298	-PRON-	False	False	X	PRON	4
# do	1300	do	False	False	xx	VERB	25
# n't	1302	not	False	False	x'x	ADV	15
# even	1306	even	False	False	xxxx	ADV	108
# know	1311	know	False	False	xxxx	VERB	78
# why	1316	why	False	False	xxx	ADV	161
# though	1320	though	False	False	xxxx	ADV	151
#
# 	1326
# 	False	True
# 	SPACE	0
# I	1327	-PRON-	False	False	X	PRON	4
# do	1329	do	False	False	xx	VERB	25
# n't	1331	not	False	False	x'x	ADV	15
# even	1335	even	False	False	xxxx	ADV	108
# know	1340	know	False	False	xxxx	VERB	78
# why	1345	why	False	False	xxx	ADV	161
# though	1349	though	False	False	xxxx	ADV	151
#
# 	1355
# 	False	True
# 	SPACE	0
# I	1356	-PRON-	False	False	X	PRON	4
# just	1358	just	False	False	xxxx	ADV	38
# want	1363	want	False	False	xxxx	VERB	107
# to	1368	to	False	False	xx	PART	5
# put	1371	put	False	False	xxx	VERB	232
# my	1375	-PRON-	False	False	xx	DET	34
# weight	1378	weight	False	False	xxxx	NOUN	773
# on	1385	on	False	False	xx	ADP	20
# you	1388	-PRON-	False	False	xxx	PRON	9
#
# 	1391
# 	False	True
# 	SPACE	0
# Switch	1392	switch	False	False	Xxxxx	VERB	14367
# it	1399	-PRON-	False	False	xx	PRON	10
# ,	1401	,	True	False	,	PUNCT	2
# smoke	1403	smoke	False	False	xxxx	VERB	1306
# it	1409	-PRON-	False	False	xx	PRON	10
# ,	1411	,	True	False	,	PUNCT	2
# I'mma	1413	I'mma	False	False	X'xxx	PROPN	0
# sway	1419	sway	False	False	xxxx	VERB	10992
# on	1424	on	False	False	xx	ADP	20
# you	1427	-PRON-	False	False	xxx	PRON	9
#
# 	1430
# 	False	True
# 	SPACE	0
# Know	1431	know	False	False	Xxxx	VERB	6618
# I	1436	-PRON-	False	False	X	PRON	4
# should	1438	should	False	False	xxxx	AUX	109
# n't	1444	not	False	False	x'x	ADV	15
# ,	1447	,	True	False	,	PUNCT	2
# I'mma	1449	I'mma	False	False	X'xxx	PROPN	0
# wait	1455	wait	False	False	xxxx	VERB	485
# on	1460	on	False	False	xx	ADP	20
# you	1463	-PRON-	False	False	xxx	PRON	9
#
# 	1466
# 	False	True
# 	SPACE	0
# I	1467	-PRON-	False	False	X	PRON	4
# do	1469	do	False	False	xx	VERB	25
# n't	1471	not	False	False	x'x	ADV	15
# even	1475	even	False	False	xxxx	ADV	108
# know	1480	know	False	False	xxxx	VERB	78
# why	1485	why	False	False	xxx	ADV	161
# though	1489	though	False	False	xxxx	ADV	151
#
# 	1495
# 	False	True
# 	SPACE	0
# I	1496	-PRON-	False	False	X	PRON	4
# just	1498	just	False	False	xxxx	ADV	38
# want	1503	want	False	False	xxxx	VERB	107
# to	1508	to	False	False	xx	PART	5
# put	1511	put	False	False	xxx	VERB	232
# my	1515	-PRON-	False	False	xx	DET	34
# weight	1518	weight	False	False	xxxx	NOUN	773
# on	1525	on	False	False	xx	ADP	20
# you	1528	-PRON-	False	False	xxx	PRON	9
#
# 	1531
# 	False	True
# 	SPACE	0
# Switch	1532	switch	False	False	Xxxxx	VERB	14367
# it	1539	-PRON-	False	False	xx	PRON	10
# ,	1541	,	True	False	,	PUNCT	2
# smoke	1543	smoke	False	False	xxxx	VERB	1306
# it	1549	-PRON-	False	False	xx	PRON	10
# ,	1551	,	True	False	,	PUNCT	2
# I'mma	1553	I'mma	False	False	X'xxx	PROPN	0
# sway	1559	sway	False	False	xxxx	VERB	10992
# on	1564	on	False	False	xx	ADP	20
# you	1567	-PRON-	False	False	xxx	PRON	9
#
# 	1570
# 	False	True
# 	SPACE	0
# Know	1571	know	False	False	Xxxx	VERB	6618
# I	1576	-PRON-	False	False	X	PRON	4
# should	1578	should	False	False	xxxx	AUX	109
# n't	1584	not	False	False	x'x	ADV	15
# ,	1587	,	True	False	,	PUNCT	2
# I'mma	1589	I'mma	False	False	X'xxx	PROPN	0
# wait	1595	wait	False	False	xxxx	VERB	485
# on	1600	on	False	False	xx	ADP	20
# you	1603	-PRON-	False	False	xxx	PRON	9
#
# 	1606
# 	False	True
# 	SPACE	0
# I	1607	-PRON-	False	False	X	PRON	4
# do	1609	do	False	False	xx	VERB	25
# n't	1611	not	False	False	x'x	ADV	15
# even	1615	even	False	False	xxxx	ADV	108
# know	1620	know	False	False	xxxx	VERB	78
# why	1625	why	False	False	xxx	ADV	161
# though	1629	though	False	False	xxxx	ADV	151
#
# 	1635
# 	False	True
# 	SPACE	0
# I	1636	-PRON-	False	False	X	PRON	4
# do	1638	do	False	False	xx	VERB	25
# n't	1640	not	False	False	x'x	ADV	15
# even	1644	even	False	False	xxxx	ADV	108
# know	1649	know	False	False	xxxx	VERB	78
# why	1654	why	False	False	xxx	ADV	161
# though	1658	though	False	False	xxxx	ADP	151
#
# 	1664
# 	False	True
# 	SPACE	0

# %%
for sent in doc.sents:
    print(sent)
# Out:
# You know what to say on my way out
# Hit me with the "Hey, been a while"
#
# Now I'm going straight through the fire, fire
#
# (I don't even know why though)
# Get me on a wave then you fade out
# Hit me with the light, got me tired
#
# I should get away from you, I know, I know
#
# (I don't even know why though)
# High hopes, I fall for the cycle
# High low, I'm on on a spiral
# Love me, wide open then leave me
#
# I don't (I don't even know why though)
#
# I just want to put my weight on you
#
# Switch it, smoke it, I'mma sway on you
#
# Know
# I shouldn't
# , I'mma wait on you
#
# I don't even know why though
# I just want to put my weight on you
#
# Switch it, smoke it, I'mma sway on you
#
# Know
# I shouldn't
# , I'mma wait on you
#
# I don't even know why though
# I don't even know why though
#
# Maybe it's the love that you show me
#
# Make my body feel like it's holy
#
# (Feel too good to say you hurt too much, too late)
#
# You're just what I need (I don't even know why though)
# High hopes, I fall for the cycle
# High low, I'm on on a spiral
# Love me
# , wide open then leave me
#
# I don't (I don't even know why though)
#
# I just want to put my weight on you
#
# Switch it, smoke it, I'mma sway on you
#
# Know
# I shouldn't
# , I'mma wait on you
#
# I don't even know why though
# I just want to put my weight on you
#
# Switch it, smoke it, I'mma sway on you
#
# Know
# I shouldn't
# , I'mma wait on you
#
# I don't even know why though
# I don't even know why though
# I just want to put my weight on you
#
# Switch it, smoke it, I'mma sway on you
#
# Know
# I shouldn't
# , I'mma wait on you
#
# I don't even know why though
# I just want to put my weight on you
#
# Switch it, smoke it, I'mma sway on you
#
# Know
# I shouldn't
# , I'mma wait on you
#
# I don't even know why though
# I don't even know why though

# %%
print([(token.text, token.tag_) for token in doc])
# Out:
# [('\n', '_SP'), ('You', 'PRP'), ('know', 'VBP'), ('what', 'WP'), ('to', 'TO'), ('say', 'VB'), ('on', 'IN'), ('my', 'PRP$'), ('way', 'NN'), ('out', 'RB'), ('\n', '_SP'), ('Hit', 'VB'), ('me', 'PRP'), ('with', 'IN'), ('the', 'DT'), ('"', '``'), ('Hey', 'UH'), (',', ','), ('been', 'VBN'), ('a', 'DT'), ('while', 'NN'), ('"', '``'), ('\n', '_SP'), ('Now', 'RB'), ('I', 'PRP'), ("'m", 'VBP'), ('going', 'VBG'), ('straight', 'RB'), ('through', 'IN'), ('the', 'DT'), ('fire', 'NN'), (',', ','), ('fire', 'NN'), ('\n', '_SP'), ('(', '-LRB-'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('know', 'VB'), ('why', 'WRB'), ('though', 'RB'), (')', '-RRB-'), ('\n', '_SP'), ('Get', 'VB'), ('me', 'PRP'), ('on', 'IN'), ('a', 'DT'), ('wave', 'NN'), ('then', 'RB'), ('you', 'PRP'), ('fade', 'VBP'), ('out', 'RP'), ('\n', '_SP'), ('Hit', 'VB'), ('me', 'PRP'), ('with', 'IN'), ('the', 'DT'), ('light', 'NN'), (',', ','), ('got', 'VBD'), ('me', 'PRP'), ('tired', 'JJ'), ('\n', '_SP'), ('I', 'PRP'), ('should', 'MD'), ('get', 'VB'), ('away', 'RB'), ('from', 'IN'), ('you', 'PRP'), (',', ','), ('I', 'PRP'), ('know', 'VBP'), (',', ','), ('I', 'PRP'), ('know', 'VBP'), ('\n', '_SP'), ('(', '-LRB-'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('know', 'VB'), ('why', 'WRB'), ('though', 'RB'), (')', '-RRB-'), ('\n', '_SP'), ('High', 'JJ'), ('hopes', 'NNS'), (',', ','), ('I', 'PRP'), ('fall', 'VBP'), ('for', 'IN'), ('the', 'DT'), ('cycle', 'NN'), ('\n', '_SP'), ('High', 'JJ'), ('low', 'NN'), (',', ','), ('I', 'PRP'), ("'m", 'VBP'), ('on', 'RP'), ('on', 'IN'), ('a', 'DT'), ('spiral', 'JJ'), ('\n', '_SP'), ('Love', 'VB'), ('me', 'PRP'), (',', ','), ('wide', 'RB'), ('open', 'JJ'), ('then', 'RB'), ('leave', 'VB'), ('me', 'PRP'), ('\n', '_SP'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('(', '-LRB-'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('know', 'VB'), ('why', 'WRB'), ('though', 'RB'), (')', '-RRB-'), ('\n', '_SP'), ('I', 'PRP'), ('just', 'RB'), ('want', 'VBP'), ('to', 'TO'), ('put', 'VB'), ('my', 'PRP$'), ('weight', 'NN'), ('on', 'IN'), ('you', 'PRP'), ('\n', '_SP'), ('Switch', 'VB'), ('it', 'PRP'), (',', ','), ('smoke', 'VB'), ('it', 'PRP'), (',', ','), ("I'mma", 'NNP'), ('sway', 'VB'), ('on', 'IN'), ('you', 'PRP'), ('\n', '_SP'), ('Know', 'VBP'), ('I', 'PRP'), ('should', 'MD'), ("n't", 'RB'), (',', ','), ("I'mma", 'NNP'), ('wait', 'VB'), ('on', 'IN'), ('you', 'PRP'), ('\n', '_SP'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('know', 'VB'), ('why', 'WRB'), ('though', 'RB'), ('\n', '_SP'), ('I', 'PRP'), ('just', 'RB'), ('want', 'VBP'), ('to', 'TO'), ('put', 'VB'), ('my', 'PRP$'), ('weight', 'NN'), ('on', 'IN'), ('you', 'PRP'), ('\n', '_SP'), ('Switch', 'VB'), ('it', 'PRP'), (',', ','), ('smoke', 'VB'), ('it', 'PRP'), (',', ','), ("I'mma", 'NNP'), ('sway', 'VB'), ('on', 'IN'), ('you', 'PRP'), ('\n', '_SP'), ('Know', 'VBP'), ('I', 'PRP'), ('should', 'MD'), ("n't", 'RB'), (',', ','), ("I'mma", 'NNP'), ('wait', 'VB'), ('on', 'IN'), ('you', 'PRP'), ('\n', '_SP'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('know', 'VB'), ('why', 'WRB'), ('though', 'RB'), ('\n', '_SP'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('know', 'VB'), ('why', 'WRB'), ('though', 'IN'), ('\n', '_SP'), ('Maybe', 'RB'), ('it', 'PRP'), ("'s", 'VBZ'), ('the', 'DT'), ('love', 'NN'), ('that', 'WDT'), ('you', 'PRP'), ('show', 'VBP'), ('me', 'PRP'), ('\n', '_SP'), ('Make', 'VB'), ('my', 'PRP$'), ('body', 'NN'), ('feel', 'VB'), ('like', 'IN'), ('it', 'PRP'), ("'s", 'VBZ'), ('holy', 'JJ'), ('\n', '_SP'), ('(', '-LRB-'), ('Feel', 'VB'), ('too', 'RB'), ('good', 'JJ'), ('to', 'TO'), ('say', 'VB'), ('you', 'PRP'), ('hurt', 'VB'), ('too', 'RB'), ('much', 'RB'), (',', ','), ('too', 'RB'), ('late', 'RB'), (')', '-RRB-'), ('\n', '_SP'), ('You', 'PRP'), ("'re", 'VBP'), ('just', 'RB'), ('what', 'WP'), ('I', 'PRP'), ('need', 'VBP'), ('(', '-LRB-'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('know', 'V ...

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# I'mma ORG
# I'mma ORG
# I'mma ORG
# I'mma ORG
# I'mma ORG
# I'mma ORG

# %%
from nltk.chunk import conlltags2tree

iob_tagged = [
   ( 
    token.text,
    token.tag_,
    "{0}-{1}".format(token.ent_iob_, token.ent_type_) if token.ent_iob_ != 'O' else token.ent_iob_
   ) for token in doc
       ]

print(conlltags2tree(iob_tagged))
# Out:
# (S
#
# /_SP
#   You/PRP
#   know/VBP
#   what/WP
#   to/TO
#   say/VB
#   on/IN
#   my/PRP$
#   way/NN
#   out/RB
#
# /_SP
#   Hit/VB
#   me/PRP
#   with/IN
#   the/DT
#   "/``
#   Hey/UH
#   ,/,
#   been/VBN
#   a/DT
#   while/NN
#   "/``
#
# /_SP
#   Now/RB
#   I/PRP
#   'm/VBP
#   going/VBG
#   straight/RB
#   through/IN
#   the/DT
#   fire/NN
#   ,/,
#   fire/NN
#
# /_SP
#   (/-LRB-
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#   )/-RRB-
#
# /_SP
#   Get/VB
#   me/PRP
#   on/IN
#   a/DT
#   wave/NN
#   then/RB
#   you/PRP
#   fade/VBP
#   out/RP
#
# /_SP
#   Hit/VB
#   me/PRP
#   with/IN
#   the/DT
#   light/NN
#   ,/,
#   got/VBD
#   me/PRP
#   tired/JJ
#
# /_SP
#   I/PRP
#   should/MD
#   get/VB
#   away/RB
#   from/IN
#   you/PRP
#   ,/,
#   I/PRP
#   know/VBP
#   ,/,
#   I/PRP
#   know/VBP
#
# /_SP
#   (/-LRB-
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#   )/-RRB-
#
# /_SP
#   High/JJ
#   hopes/NNS
#   ,/,
#   I/PRP
#   fall/VBP
#   for/IN
#   the/DT
#   cycle/NN
#
# /_SP
#   High/JJ
#   low/NN
#   ,/,
#   I/PRP
#   'm/VBP
#   on/RP
#   on/IN
#   a/DT
#   spiral/JJ
#
# /_SP
#   Love/VB
#   me/PRP
#   ,/,
#   wide/RB
#   open/JJ
#   then/RB
#   leave/VB
#   me/PRP
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   (/-LRB-
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#   )/-RRB-
#
# /_SP
#   I/PRP
#   just/RB
#   want/VBP
#   to/TO
#   put/VB
#   my/PRP$
#   weight/NN
#   on/IN
#   you/PRP
#
# /_SP
#   Switch/VB
#   it/PRP
#   ,/,
#   smoke/VB
#   it/PRP
#   ,/,
#   (ORG I'mma/NNP)
#   sway/VB
#   on/IN
#   you/PRP
#
# /_SP
#   Know/VBP
#   I/PRP
#   should/MD
#   n't/RB
#   ,/,
#   I'mma/NNP
#   wait/VB
#   on/IN
#   you/PRP
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#
# /_SP
#   I/PRP
#   just/RB
#   want/VBP
#   to/TO
#   put/VB
#   my/PRP$
#   weight/NN
#   on/IN
#   you/PRP
#
# /_SP
#   Switch/VB
#   it/PRP
#   ,/,
#   smoke/VB
#   it/PRP
#   ,/,
#   (ORG I'mma/NNP)
#   sway/VB
#   on/IN
#   you/PRP
#
# /_SP
#   Know/VBP
#   I/PRP
#   should/MD
#   n't/RB
#   ,/,
#   I'mma/NNP
#   wait/VB
#   on/IN
#   you/PRP
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/IN
#
# /_SP
#   Maybe/RB
#   it/PRP
#   's/VBZ
#   the/DT
#   love/NN
#   that/WDT
#   you/PRP
#   show/VBP
#   me/PRP
#
# /_SP
#   Make/VB
#   my/PRP$
#   body/NN
#   feel/VB
#   like/IN
#   it/PRP
#   's/VBZ
#   holy/JJ
#
# /_SP
#   (/-LRB-
#   Feel/VB
#   too/RB
#   good/JJ
#   to/TO
#   say/VB
#   you/PRP
#   hurt/VB
#   too/RB
#   much/RB
#   ,/,
#   too/RB
#   late/RB
#   )/-RRB-
#
# /_SP
#   You/PRP
#   're/VBP
#   just/RB
#   what/WP
#   I/PRP
#   need/VBP
#   (/-LRB-
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#   )/-RRB-
#
# /_SP
#   High/JJ
#   hopes/NNS
#   ,/,
#   I/PRP
#   fall/VBP
#   for/IN
#   the/DT
#   cycle/NN
#
# /_SP
#   High/JJ
#   low/NN
#   ,/,
#   I/PRP
#   'm/VBP
#   on/RP
#   on/IN
#   a/DT
#   spiral/JJ
#
# /_SP
#   Love/VB
#   me/PRP
#   ,/,
#   wide/RB
#   open/JJ
#   then/RB
#   leave/VB
#   me/PRP
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   (/-LRB-
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#   )/-RRB-
#
# /_SP
#   I/PRP
#   just/RB
#   want/VBP
#   to/TO
#   put/VB
#   my/PRP$
#   weight/NN
#   on/IN
#   you/PRP
#
# /_SP
#   Switch/VB
#   it/PRP
#   ,/,
#   smoke/VB
#   it/PRP
#   ,/,
#   (ORG I'mma/NNP)
#   sway/VB
#   on/IN
#   you/PRP
#
# /_SP
#   Know/VBP
#   I/PRP
#   should/MD
#   n't/RB
#   ,/,
#   I'mma/NNP
#   wait/VB
#   on/IN
#   you/PRP
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#
# /_SP
#   I/PRP
#   just/RB
#   want/VBP
#   to/TO
#   put/VB
#   my/PRP$
#   weight/NN
#   on/IN
#   you/PRP
#
# /_SP
#   Switch/VB
#   it/PRP
#   ,/,
#   smoke/VB
#   it/PRP
#   ,/,
#   (ORG I'mma/NNP)
#   sway/VB
#   on/IN
#   you/PRP
#
# /_SP
#   Know/VBP
#   I/PRP
#   should/MD
#   n't/RB
#   ,/,
#   I'mma/NNP
#   wait/VB
#   on/IN
#   you/PRP
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#
# /_SP
#   I/PRP
#   just/RB
#   want/VBP
#   to/TO
#   put/VB
#   my/PRP$
#   weight/NN
#   on/IN
#   you/PRP
#
# /_SP
#   Switch/VB
#   it/PRP
#   ,/,
#   smoke/VB
#   it/PRP
#   ,/,
#   (ORG I'mma/NNP)
#   sway/VB
#   on/IN
#   you/PRP
#
# /_SP
#   Know/VBP
#   I/PRP
#   should/MD
#   n't/RB
#   ,/,
#   I'mma/NNP
#   wait/VB
#   on/IN
#   you/PRP
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#
# /_SP
#   I/PRP
#   just/RB
#   want/VBP
#   to/TO
#   put/VB
#   my/PRP$
#   weight/NN
#   on/IN
#   you/PRP
#
# /_SP
#   Switch/VB
#   it/PRP
#   ,/,
#   smoke/VB
#   it/PRP
#   ,/,
#   (ORG I'mma/NNP)
#   sway/VB
#   on/IN
#   you/PRP
#
# /_SP
#   Know/VBP
#   I/PRP
#   should/MD
#   n't/RB
#   ,/,
#   I'mma/NNP
#   wait/VB
#   on/IN
#   you/PRP
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/RB
#
# /_SP
#   I/PRP
#   do/VBP
#   n't/RB
#   even/RB
#   know/VB
#   why/WRB
#   though/IN
#
# /_SP)

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr"></br>You know what to say on my way out</br>Hit me with the &quot;Hey, been a while&quot;</br>Now I'm going straight through the fire, fire</br>(I don't even know why though)</br>Get me on a wave then you fade out</br>Hit me with the light, got me tired</br>I should get away from you, I know, I know</br>(I don't even know why though)</br>High hopes, I fall for the cycle</br>High low, I'm on on a spiral</br>Love me, wide open then leave me</br>I don't (I don't even know why though)</br>I just want to put my weight on you</br>Switch it, smoke it,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     I'mma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sway on you</br>Know I shouldn't, I'mma wait on you</br>I don't even know why though</br>I just want to put my weight on you</br>Switch it, smoke it,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     I'mma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sway on you</br>Know I shouldn't, I'mma wait on you</br>I don't even know why though</br>I don't even know why though</br>Maybe it's the love that you show me</br>Make my body feel like it's holy</br>(Feel too good to say you hurt too much, too late)</br>You're just what I need (I don't even know why though)</br>High hopes, I fall for the cycle</br>High low, I'm on on a spiral</br>Love me, wide open then leave me</br>I don't (I don't even know why though)</br>I just want to put my weight on you</br>Switch it, smoke it,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     I'mma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sway on you</br>Know I shouldn't, I'mma wait on you</br>I don't even know why though</br>I just want to put my weight on you</br>Switch it, smoke it,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     I'mma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sway on you</br>Know I shouldn't, I'mma wait on you</br>I don't even know why though</br>I don't even know why though</br>I just want to put my weight on you</br>Switch it, smoke it,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     I'mma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sway on you</br>Know I shouldn't, I'mma wait on you</br>I don't even know why though</br>I just want to put my weight on you</br>Switch it, smoke it,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     I'mma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sway on you
# Know I shouldn't, I'mma wait on you
# I don't even know why though
# I don't even know why though
# </div>

# %%
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.label_, chunk.root.text)
# Out:
# You NP You
# what NP what
# my way NP way
# me NP me
# a while NP while
# I NP I
# the fire NP fire
# I NP I
# me NP me
# a wave NP wave
# you NP you
# me NP me
# the light NP light
# me NP me
# I NP I
# you NP you
# I NP I
# I NP I
# I NP I
# I NP I
# the cycle NP cycle
# I NP I
# a spiral
# Love me NP me
# me NP me
# I NP I
# I NP I
# I NP I
# my weight NP weight
# you NP you
# it NP it
# it NP it
# I'mma NP I'mma
# you NP you
# I NP I
# I'mma NP I'mma
# you NP you
# I NP I
# I NP I
# my weight NP weight
# you NP you
# it NP it
# it NP it
# I'mma NP I'mma
# you NP you
# I NP I
# I'mma NP I'mma
# you NP you
# I NP I
# I NP I
# it NP it
# the love NP love
# you NP you
# me NP me
# my body NP body
# it NP it
# you NP you
# You NP You
# just what NP what
# I NP I
# I NP I
# I NP I
# the cycle NP cycle
# I NP I
# a spiral
# Love me NP me
# me NP me
# I NP I
# I NP I
# I NP I
# my weight NP weight
# you NP you
# it NP it
# it NP it
# I'mma NP I'mma
# you NP you
# I NP I
# I'mma NP I'mma
# you NP you
# I NP I
# I NP I
# my weight NP weight
# you NP you
# it NP it
# it NP it
# I'mma NP I'mma
# you NP you
# I NP I
# I'mma NP I'mma
# you NP you
# I NP I
# I NP I
# I NP I
# my weight NP weight
# you NP you
# it NP it
# it NP it
# I'mma NP I'mma
# you NP you
# I NP I
# I'mma NP I'mma
# you NP you
# I NP I
# I NP I
# my weight NP weight
# you NP you
# it NP it
# it NP it
# I'mma NP I'mma
# you NP you
# I NP I
# I'mma NP I'mma
# you NP you
# I NP I
# I NP I

# %%
for token in doc:
    print("{0}/{1} <--{2}-- {3}/{4}".format(
        token.text, token.tag_, token.dep_, token.head.text, token.head.tag_))
# Out:
# /_SP <---- You/PRP
# You/PRP <--nsubj-- know/VBP
# know/VBP <--parataxis-- been/VBN
# what/WP <--dobj-- say/VB
# to/TO <--aux-- say/VB
# say/VB <--xcomp-- know/VBP
# on/IN <--prep-- say/VB
# my/PRP$ <--poss-- way/NN
# way/NN <--pobj-- on/IN
# out/RB <--prep-- way/NN
#
# /_SP <---- out/RB
# Hit/VB <--dep-- know/VBP
# me/PRP <--dobj-- Hit/VB
# with/IN <--prep-- Hit/VB
# the/DT <--pobj-- with/IN
# "/`` <--punct-- been/VBN
# Hey/UH <--intj-- been/VBN
# ,/, <--punct-- been/VBN
# been/VBN <--ROOT-- been/VBN
# a/DT <--det-- while/NN
# while/NN <--attr-- been/VBN
# "/`` <--punct-- while/NN
#
# /_SP <---- "/``
# Now/RB <--advmod-- going/VBG
# I/PRP <--nsubj-- going/VBG
# 'm/VBP <--aux-- going/VBG
# going/VBG <--ROOT-- going/VBG
# straight/RB <--advmod-- through/IN
# through/IN <--prep-- going/VBG
# the/DT <--det-- fire/NN
# fire/NN <--pobj-- through/IN
# ,/, <--punct-- going/VBG
# fire/NN <--npadvmod-- going/VBG
#
# /_SP <---- fire/NN
# (/-LRB- <--punct-- know/VB
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ROOT-- know/VB
# why/WRB <--advmod-- Get/VB
# though/RB <--advmod-- why/WRB
# )/-RRB- <--punct-- Get/VB
#
# /_SP <---- )/-RRB-
# Get/VB <--advcl-- fade/VBP
# me/PRP <--dobj-- Get/VB
# on/IN <--prep-- Get/VB
# a/DT <--det-- wave/NN
# wave/NN <--pobj-- on/IN
# then/RB <--advmod-- fade/VBP
# you/PRP <--nsubj-- fade/VBP
# fade/VBP <--ccomp-- know/VB
# out/RP <--prt-- fade/VBP
#
# /_SP <---- out/RP
# Hit/VB <--npadvmod-- fade/VBP
# me/PRP <--dobj-- Hit/VB
# with/IN <--prep-- Hit/VB
# the/DT <--det-- light/NN
# light/NN <--pobj-- with/IN
# ,/, <--punct-- fade/VBP
# got/VBD <--conj-- fade/VBP
# me/PRP <--nsubj-- tired/JJ
# tired/JJ <--ccomp-- got/VBD
#
# /_SP <---- tired/JJ
# I/PRP <--nsubj-- get/VB
# should/MD <--aux-- get/VB
# get/VB <--ROOT-- get/VB
# away/RB <--advmod-- get/VB
# from/IN <--prep-- away/RB
# you/PRP <--pobj-- from/IN
# ,/, <--punct-- get/VB
# I/PRP <--nsubj-- know/VBP
# know/VBP <--parataxis-- get/VB
# ,/, <--punct-- know/VBP
# I/PRP <--nsubj-- know/VBP
# know/VBP <--parataxis-- know/VBP
#
# /_SP <---- know/VBP
# (/-LRB- <--punct-- know/VB
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ROOT-- know/VB
# why/WRB <--advmod-- fall/VBP
# though/RB <--mark-- fall/VBP
# )/-RRB- <--punct-- hopes/NNS
#
# /_SP <---- )/-RRB-
# High/JJ <--amod-- hopes/NNS
# hopes/NNS <--parataxis-- fall/VBP
# ,/, <--punct-- fall/VBP
# I/PRP <--nsubj-- fall/VBP
# fall/VBP <--advcl-- 'm/VBP
# for/IN <--prep-- fall/VBP
# the/DT <--det-- cycle/NN
# cycle/NN <--pobj-- for/IN
#
# /_SP <---- cycle/NN
# High/JJ <--advmod-- low/NN
# low/NN <--advmod-- fall/VBP
# ,/, <--punct-- 'm/VBP
# I/PRP <--nsubj-- 'm/VBP
# 'm/VBP <--ccomp-- know/VB
# on/RP <--prep-- 'm/VBP
# on/IN <--prep-- 'm/VBP
# a/DT <--det-- me/PRP
# spiral/JJ <--amod-- me/PRP
#
# /_SP <---- spiral/JJ
# Love/VB <--compound-- me/PRP
# me/PRP <--pobj-- on/IN
# ,/, <--punct-- 'm/VBP
# wide/RB <--advmod-- open/JJ
# open/JJ <--acomp-- 'm/VBP
# then/RB <--advmod-- leave/VB
# leave/VB <--dep-- 'm/VBP
# me/PRP <--dobj-- leave/VB
#
# /_SP <---- me/PRP
# I/PRP <--nsubj-- do/VBP
# do/VBP <--ROOT-- do/VBP
# n't/RB <--neg-- do/VBP
# (/-LRB- <--punct-- know/VB
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--parataxis-- do/VBP
# why/WRB <--advmod-- do/VBP
# though/RB <--advmod-- why/WRB
# )/-RRB- <--punct-- though/RB
#
# /_SP <---- )/-RRB-
# I/PRP <--nsubj-- want/VBP
# just/RB <--advmod-- want/VBP
# want/VBP <--ROOT-- want/VBP
# to/TO <--aux-- put/VB
# put/VB <--xcomp-- want/VBP
# my/PRP$ <--poss-- weight/NN
# weight/NN <--dobj-- put/VB
# on/IN <--prep-- put/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Switch/VB <--advcl-- smoke/VB
# it/PRP <--dobj-- Switch/VB
# ,/, <--punct-- smoke/VB
# smoke/VB <--ROOT-- smoke/VB
# it/PRP <--dobj-- smoke/VB
# ,/, <--punct-- smoke/VB
# I'mma/NNP <--nsubj-- sway/VB
# sway/VB <--conj-- smoke/VB
# on/IN <--prep-- sway/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Know/VBP <--ROOT-- Know/VBP
# I/PRP <--nsubj-- should/MD
# should/MD <--ROOT-- should/MD
# n't/RB <--neg-- should/MD
# ,/, <--punct-- wait/VB
# I'mma/NNP <--nsubj-- wait/VB
# wait/VB <--ROOT-- wait/VB
# on/IN <--prep-- wait/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ROOT-- know/VB
# why/WRB <--advmod-- want/VBP
# though/RB <--prep-- want/VBP
#
# /_SP <---- though/RB
# I/PRP <--nsubj-- want/VBP
# just/RB <--advmod-- want/VBP
# want/VBP <--ccomp-- know/VB
# to/TO <--aux-- put/VB
# put/VB <--xcomp-- want/VBP
# my/PRP$ <--poss-- weight/NN
# weight/NN <--dobj-- put/VB
# on/IN <--prep-- put/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Switch/VB <--advcl-- smoke/VB
# it/PRP <--dobj-- Switch/VB
# ,/, <--punct-- smoke/VB
# smoke/VB <--ROOT-- smoke/VB
# it/PRP <--dobj-- smoke/VB
# ,/, <--punct-- smoke/VB
# I'mma/NNP <--nsubj-- sway/VB
# sway/VB <--conj-- smoke/VB
# on/IN <--prep-- sway/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Know/VBP <--ROOT-- Know/VBP
# I/PRP <--nsubj-- should/MD
# should/MD <--ROOT-- should/MD
# n't/RB <--neg-- should/MD
# ,/, <--punct-- wait/VB
# I'mma/NNP <--nsubj-- wait/VB
# wait/VB <--ROOT-- wait/VB
# on/IN <--prep-- wait/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ROOT-- know/VB
# why/WRB <--advmod-- know/VB
# though/RB <--prep-- know/VB
#
# /_SP <---- though/RB
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ccomp-- know/VB
# why/WRB <--prep-- know/VB
# though/IN <--advmod-- why/WRB
#
# /_SP <---- though/IN
# Maybe/RB <--advmod-- 's/VBZ
# it/PRP <--nsubj-- 's/VBZ
# 's/VBZ <--ROOT-- 's/VBZ
# the/DT <--det-- love/NN
# love/NN <--attr-- 's/VBZ
# that/WDT <--mark-- show/VBP
# you/PRP <--nsubj-- show/VBP
# show/VBP <--ccomp-- 's/VBZ
# me/PRP <--dative-- show/VBP
#
# /_SP <---- me/PRP
# Make/VB <--ROOT-- Make/VB
# my/PRP$ <--poss-- body/NN
# body/NN <--nsubj-- feel/VB
# feel/VB <--ccomp-- Make/VB
# like/IN <--mark-- 's/VBZ
# it/PRP <--nsubj-- 's/VBZ
# 's/VBZ <--advcl-- feel/VB
# holy/JJ <--acomp-- 's/VBZ
#
# /_SP <---- holy/JJ
# (/-LRB- <--punct-- Feel/VB
# Feel/VB <--ROOT-- Feel/VB
# too/RB <--advmod-- good/JJ
# good/JJ <--acomp-- Feel/VB
# to/TO <--aux-- say/VB
# say/VB <--xcomp-- good/JJ
# you/PRP <--nsubj-- hurt/VB
# hurt/VB <--ccomp-- say/VB
# too/RB <--advmod-- much/RB
# much/RB <--advmod-- late/RB
# ,/, <--punct-- late/RB
# too/RB <--advmod-- late/RB
# late/RB <--advmod-- hurt/VB
# )/-RRB- <--punct-- late/RB
#
# /_SP <---- )/-RRB-
# You/PRP <--nsubj-- 're/VBP
# 're/VBP <--ccomp-- 'm/VBP
# just/RB <--advmod-- what/WP
# what/WP <--dobj-- need/VBP
# I/PRP <--nsubj-- need/VBP
# need/VBP <--ccomp-- 're/VBP
# (/-LRB- <--punct-- know/VB
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--parataxis-- need/VBP
# why/WRB <--advmod-- fall/VBP
# though/RB <--mark-- fall/VBP
# )/-RRB- <--punct-- hopes/NNS
#
# /_SP <---- )/-RRB-
# High/JJ <--amod-- hopes/NNS
# hopes/NNS <--parataxis-- fall/VBP
# ,/, <--punct-- fall/VBP
# I/PRP <--nsubj-- fall/VBP
# fall/VBP <--ccomp-- know/VB
# for/IN <--prep-- fall/VBP
# the/DT <--det-- cycle/NN
# cycle/NN <--pobj-- for/IN
#
# /_SP <---- cycle/NN
# High/JJ <--advmod-- low/NN
# low/NN <--advmod-- fall/VBP
# ,/, <--punct-- 'm/VBP
# I/PRP <--nsubj-- 'm/VBP
# 'm/VBP <--ROOT-- 'm/VBP
# on/RP <--prep-- 'm/VBP
# on/IN <--prep-- 'm/VBP
# a/DT <--det-- me/PRP
# spiral/JJ <--amod-- me/PRP
#
# /_SP <---- spiral/JJ
# Love/VB <--compound-- me/PRP
# me/PRP <--pobj-- on/IN
# ,/, <--punct-- leave/VB
# wide/RB <--advmod-- open/JJ
# open/JJ <--advmod-- leave/VB
# then/RB <--advmod-- leave/VB
# leave/VB <--ROOT-- leave/VB
# me/PRP <--dobj-- leave/VB
#
# /_SP <---- me/PRP
# I/PRP <--nsubj-- do/VBP
# do/VBP <--ROOT-- do/VBP
# n't/RB <--neg-- do/VBP
# (/-LRB- <--punct-- know/VB
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--parataxis-- do/VBP
# why/WRB <--advmod-- do/VBP
# though/RB <--advmod-- why/WRB
# )/-RRB- <--punct-- though/RB
#
# /_SP <---- )/-RRB-
# I/PRP <--nsubj-- want/VBP
# just/RB <--advmod-- want/VBP
# want/VBP <--ROOT-- want/VBP
# to/TO <--aux-- put/VB
# put/VB <--xcomp-- want/VBP
# my/PRP$ <--poss-- weight/NN
# weight/NN <--dobj-- put/VB
# on/IN <--prep-- put/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Switch/VB <--advcl-- smoke/VB
# it/PRP <--dobj-- Switch/VB
# ,/, <--punct-- smoke/VB
# smoke/VB <--ROOT-- smoke/VB
# it/PRP <--dobj-- smoke/VB
# ,/, <--punct-- smoke/VB
# I'mma/NNP <--nsubj-- sway/VB
# sway/VB <--conj-- smoke/VB
# on/IN <--prep-- sway/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Know/VBP <--ROOT-- Know/VBP
# I/PRP <--nsubj-- should/MD
# should/MD <--ROOT-- should/MD
# n't/RB <--neg-- should/MD
# ,/, <--punct-- wait/VB
# I'mma/NNP <--nsubj-- wait/VB
# wait/VB <--ROOT-- wait/VB
# on/IN <--prep-- wait/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ROOT-- know/VB
# why/WRB <--advmod-- want/VBP
# though/RB <--prep-- want/VBP
#
# /_SP <---- though/RB
# I/PRP <--nsubj-- want/VBP
# just/RB <--advmod-- want/VBP
# want/VBP <--ccomp-- know/VB
# to/TO <--aux-- put/VB
# put/VB <--xcomp-- want/VBP
# my/PRP$ <--poss-- weight/NN
# weight/NN <--dobj-- put/VB
# on/IN <--prep-- put/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Switch/VB <--advcl-- smoke/VB
# it/PRP <--dobj-- Switch/VB
# ,/, <--punct-- smoke/VB
# smoke/VB <--ROOT-- smoke/VB
# it/PRP <--dobj-- smoke/VB
# ,/, <--punct-- smoke/VB
# I'mma/NNP <--nsubj-- sway/VB
# sway/VB <--conj-- smoke/VB
# on/IN <--prep-- sway/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Know/VBP <--ROOT-- Know/VBP
# I/PRP <--nsubj-- should/MD
# should/MD <--ROOT-- should/MD
# n't/RB <--neg-- should/MD
# ,/, <--punct-- wait/VB
# I'mma/NNP <--nsubj-- wait/VB
# wait/VB <--ROOT-- wait/VB
# on/IN <--prep-- wait/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ROOT-- know/VB
# why/WRB <--advmod-- know/VB
# though/RB <--prep-- know/VB
#
# /_SP <---- though/RB
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ccomp-- know/VB
# why/WRB <--advmod-- want/VBP
# though/RB <--prep-- want/VBP
#
# /_SP <---- though/RB
# I/PRP <--nsubj-- want/VBP
# just/RB <--advmod-- want/VBP
# want/VBP <--ccomp-- know/VB
# to/TO <--aux-- put/VB
# put/VB <--xcomp-- want/VBP
# my/PRP$ <--poss-- weight/NN
# weight/NN <--dobj-- put/VB
# on/IN <--prep-- put/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Switch/VB <--advcl-- smoke/VB
# it/PRP <--dobj-- Switch/VB
# ,/, <--punct-- smoke/VB
# smoke/VB <--ROOT-- smoke/VB
# it/PRP <--dobj-- smoke/VB
# ,/, <--punct-- smoke/VB
# I'mma/NNP <--nsubj-- sway/VB
# sway/VB <--conj-- smoke/VB
# on/IN <--prep-- sway/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Know/VBP <--ROOT-- Know/VBP
# I/PRP <--nsubj-- should/MD
# should/MD <--ROOT-- should/MD
# n't/RB <--neg-- should/MD
# ,/, <--punct-- wait/VB
# I'mma/NNP <--nsubj-- wait/VB
# wait/VB <--ROOT-- wait/VB
# on/IN <--prep-- wait/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ROOT-- know/VB
# why/WRB <--advmod-- want/VBP
# though/RB <--prep-- want/VBP
#
# /_SP <---- though/RB
# I/PRP <--nsubj-- want/VBP
# just/RB <--advmod-- want/VBP
# want/VBP <--ccomp-- know/VB
# to/TO <--aux-- put/VB
# put/VB <--xcomp-- want/VBP
# my/PRP$ <--poss-- weight/NN
# weight/NN <--dobj-- put/VB
# on/IN <--prep-- put/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Switch/VB <--advcl-- smoke/VB
# it/PRP <--dobj-- Switch/VB
# ,/, <--punct-- smoke/VB
# smoke/VB <--ROOT-- smoke/VB
# it/PRP <--dobj-- smoke/VB
# ,/, <--punct-- smoke/VB
# I'mma/NNP <--nsubj-- sway/VB
# sway/VB <--conj-- smoke/VB
# on/IN <--prep-- sway/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# Know/VBP <--ROOT-- Know/VBP
# I/PRP <--nsubj-- should/MD
# should/MD <--ROOT-- should/MD
# n't/RB <--neg-- should/MD
# ,/, <--punct-- wait/VB
# I'mma/NNP <--nsubj-- wait/VB
# wait/VB <--ROOT-- wait/VB
# on/IN <--prep-- wait/VB
# you/PRP <--pobj-- on/IN
#
# /_SP <---- you/PRP
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ROOT-- know/VB
# why/WRB <--advmod-- know/VB
# though/RB <--prep-- know/VB
#
# /_SP <---- though/RB
# I/PRP <--nsubj-- know/VB
# do/VBP <--aux-- know/VB
# n't/RB <--neg-- know/VB
# even/RB <--advmod-- know/VB
# know/VB <--ccomp-- know/VB
# why/WRB <--ccomp-- know/VB
# though/IN <--advmod-- why/WRB
#
# /_SP <---- though/IN

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2dc7253887b94c4ba04c407a3bec6ee1-0" class="displacy" width="39020" height="722.0" direction="ltr" style="max-width: none; height: 722.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">You</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">know</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">say</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">way</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">out</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">Hit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">me</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">the &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Hey,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">while&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">'m</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">straight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">through</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">fire,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">fire</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">
# (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentC

# %%
# nlp = spacy.load('en_core_web_lg')
print(nlp.vocab['blue'].vector)
# Out:
# [ 1.2945e-01  3.6518e-02  3.2298e-02 -6.0034e-02  3.9984e-01 -1.0302e-01
#  -5.0788e-01  7.6630e-02 -4.2292e-01  8.1573e-01 -1.8254e-01 -7.2278e-02
#  -3.5811e-01 -4.2866e-01  1.0880e-01  1.5103e-01  2.4036e-01  2.1151e+00
#  -1.1639e-01 -1.0583e+00 -5.3679e-02 -3.4066e-01 -3.8793e-01  2.2061e-01
#  -3.4530e-01 -2.9483e-01 -3.7717e-01  4.0785e-02  1.5596e-01  3.7820e-01
#  -2.3014e-01  1.0614e-01 -8.3818e-02 -1.2111e-01 -4.9809e-01 -3.1123e-01
#   1.6842e-01  5.2813e-03 -2.8166e-01 -3.3547e-01  6.3742e-01  6.1738e-02
#   6.6857e-04  2.9287e-01  7.0483e-01 -3.0640e-01 -1.0502e-01  1.5662e-02
#   3.5022e-01 -5.6460e-01 -2.7583e-01  1.4461e-01 -2.2997e-02 -6.3409e-01
#   1.0600e-01 -1.6538e-01 -3.8640e-01  4.8446e-01 -9.0255e-02 -4.4072e-01
#  -4.1374e-01 -2.2599e-01  2.6587e-01 -4.8448e-02 -2.2655e-01  1.9783e-01
#  -9.7722e-02  1.3453e-02 -2.9703e-01  3.1052e-01  2.2518e-02 -4.1471e-02
#  -1.4498e-01 -6.4198e-04 -7.4392e-02 -1.1045e-01 -1.4347e-01 -2.5305e-01
#   1.7343e-02 -4.6337e-01 -3.3628e-01 -7.7266e-03  3.2929e-01  6.5749e-01
#   5.0099e-01 -4.1894e-01  1.1152e+00  1.1415e+00  1.4792e-01 -1.2884e-01
#   2.6490e-01  4.1921e-01  6.8368e-01  1.4140e-01  2.4301e-01 -2.4716e-01
#  -1.2793e-01  3.3171e-02  2.6186e-01 -2.2869e-01  3.5403e-01  3.4218e-01
#   1.9045e-02 -1.8009e-01 -3.2421e-01 -3.2647e-01 -6.8676e-01  1.3759e-01
#   1.2011e-01  3.4420e-01 -1.0575e-01 -3.6085e-01 -3.3969e-02 -7.5959e-02
#   5.5006e-01  1.7079e-01  1.1759e-01  7.4434e-02 -1.9619e-01  1.1575e-01
#  -1.9727e-02 -8.0225e-02 -2.5875e-01  1.8083e-01  6.9465e-02  2.2434e-01
#   2.1980e-01 -9.2544e-02  1.5936e-01 -3.8112e-01 -4.3994e-02  6.4375e-02
#  -3.1658e-01 -1.1414e-01  2.8863e-01 -1.9802e-01 -1.6159e-01 -3.2779e-01
#   1.7365e-01 -2.6399e-01 -2.7416e+00  3.9465e-01  5.7405e-01  2.6489e-01
#   4.6908e-03  2.1341e-01 -3.3751e-02  1.8707e-01  2.6280e-01 -2.4634e-01
#  -1.5759e-02 -2.8078e-01  6.1048e-02  2.1249e-02 -6.1868e-01 -3.3686e-01
#  -5.7766e-01  5.4087e-01 -6.9855e-01  1.5292e-01 -2.7576e-01  3.4488e-02
#  -2.0985e-02  9.7499e-02  3.1614e-01 -1.9118e-01 -1.9921e-01 -1.9339e-01
#   2.5761e-01  2.3358e-01 -3.3192e-01  1.6347e-01 -2.4101e-01 -2.4593e-01
#  -5.3066e-02  1.0621e-01  2.5470e-01 -3.1681e-02  1.3487e-01 -5.8016e-03
#  -4.0043e-01 -1.3483e-01 -3.7817e-01 -4.2003e-01 -1.7252e-01 -7.7505e-02
#  -4.4785e-01  5.8989e-02 -6.4408e-02 -1.0683e-01  4.5613e-01  4.1441e-02
#  -9.5290e-02 -5.3396e-01  1.9519e-01 -9.5574e-02  3.5646e-01  3.0387e-01
#  -7.0282e-02  5.2516e-02 -4.1671e-01  7.1927e-02 -3.3842e-01  1.2158e-01
#  -2.5487e-02 -3.7809e-02  4.9978e-01 -2.9422e-03 -2.3537e-01  8.7716e-02
#  -7.9774e-02  5.0655e-01  6.2552e-03 -1.0660e-01  4.3767e-01  2.4726e-01
#  -3.1091e-02 -3.8611e-01  9.1349e-02 -2.0103e-01 -3.5613e-01  4.5782e-02
#  -1.4501e-01  1.9909e-01 -3.1008e-01 -2.5275e-02  5.3381e-01 -4.1398e-02
#   1.0207e-01  1.3398e-01 -6.5214e-02  4.2673e-01  6.6232e-01  4.0882e-01
#   1.4465e-01  3.3171e-01  8.2387e-02 -3.8703e-01  8.3493e-01  4.9444e-01
#  -3.6500e-01  4.1354e-02 -1.0220e-01 -1.1176e-01 -7.9963e-02 -7.6436e-02
#  -5.7894e-06 -1.3727e-01 -2.9077e-01 -2.8289e-01  2.0130e-01  3.5456e-02
#  -1.4123e-01  1.5119e-01  3.3825e-01  1.5538e-01 -1.0228e-01  4.4826e-01
#  -1.4875e-01  2.0694e-01  1.5892e-01  4.8602e-01 -8.7139e-02  6.0108e-01
#  -7.6958e-04 -8.2692e-02 -1.2079e-01  1.1397e-01 -4.9213e-01 -1.3484e-01
#  -4.9360e-01  3.5147e-01 -1.9813e-02 -7.5597e-02  3.6957e-01 -3.0950e-01
#  -2.1860e-01  3.3534e-01  1.0654e-01 -1.2387e-01 -1.4015e-01 -3.1263e-01
#  -5.2471e-01 -2.8534e-01 -2.7762e-01  8.0487e-02  6.0031e-02  5.3901e-01
#   5.5474e-01 -1.4781e-01 -5.0128e-01  1.6901e-01  5.4825e-01 -3.1938e-01
#  -7.2887e-02  3.8295e-01  2.3741e-01  5.2289e-02  1.8206e-01  4.1264e-01]

# %%
from scipy import spatial

# %%
cosine_similarity =lambda x, y: 1 - spatial.distance.cosine(x,y)
man = nlp.vocab['man'].vector
woman = nlp.vocab['woman'].vector
queen = nlp.vocab['queen'].vector
king = nlp.vocab['king'].vector
maybe_king = man - woman + queen
computed_similarities = []

for word in nlp.vocab:
    #Ignore words without vectors
    if not word.has_vector:
        continue #skip it
    
    similarity = cosine_similarity(maybe_king, word.vector)
    computed_similarities.append((word, similarity))

computed_similarities = sorted(computed_similarities, key = lambda item: -item[1])
print([w[0].text for w in computed_similarities[:10]])
# Out:
# ['Queen', 'QUEEN', 'queen', 'King', 'KING', 'king', 'KIng', 'Kings', 'KINGS', 'kings']

# %%
banana = nlp.vocab['banana']
dog = nlp.vocab['dog']
fruit = nlp.vocab['fruit']
animal = nlp.vocab['animal']

# %%
print(dog.similarity(animal), dog.similarity(fruit))
print(banana.similarity(fruit), banana.similarity(animal))
# Out:
# 0.66185343 0.23552851
# 0.67148364 0.24272855

# %%
target = nlp ("Cats are beautiful animals.")

doc1 = nlp("Dogs are awesome.")
doc2 = nlp("Some creatures are felines.")
doc3 = nlp("Dolphins are swimming mammals.")
doc4 = nlp("Coffee is for closers.")

print(target.similarity(doc1))
print(target.similarity(doc2))
print(target.similarity(doc3))
print(target.similarity(doc4))
# Out:
# 0.8901766262114666
# 0.884017190144359
# 0.7822956256736615
# 0.5744065220171272

# %%
from spacy.tokens import Doc
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# E:\Python\Anaconda\envs\python35\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\vonnj\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sentiment_analyzer = SentimentIntensityAnalyzer()

def polarity_scores(doc):
    return sentiment_analyzer.polarity_scores(doc.text)

Doc.set_extension('polarity_scores', getter=polarity_scores)
print(doc._.polarity_scores)
# Out:
# {'pos': 0.094, 'compound': 0.9274, 'neg': 0.05, 'neu': 0.856}

# %%
nlp = spacy.load('en_core_web_lg')

# %%
print(nlp.pipeline)
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger object at 0x0000018FBB82EA58>), ('parser', <spacy.pipeline.pipes.DependencyParser object at 0x0000018FA7992F48>), ('ner', <spacy.pipeline.pipes.EntityRecognizer object at 0x0000018FBB80A3A8>)]

# %%
from nltk.corpus import wordnet as wn
from spacy.tokens import Token

# %%
def penn_to_wn(tag):
    if tag.startswith('N'):
        return 'n'
    if tag.startswith('V'):
        return 'v'
    if tag.startswith('J'):
        return 'a'
    if tag.startswith('R'):
        return 'r'
    return None

# %%
class WordnetPipeline(object):
    def __init__(self, nlp):
        Token.set_extension('synset',default=None)
    
    def __call__(self, doc):
        for token in doc:
            wn_tag = penn_to_wn(token.tag_)
            if wn_tag is None:
                continue #skip it
            
            ss = wn.synsets(token.text, wn_tag)[0]
            token._.set('synset', ss)
        
        return doc

# %%
wn_pipeline = WordnetPipeline(nlp)
nlp.add_pipe(wn_pipeline)
doc = nlp("Paris is the awesome capital of France")

# %%
for token in doc:
    print(token.text, "-", token._.synset)
# Out:
# Paris - Synset('paris.n.01')
# is - Synset('be.v.01')
# the - None
# awesome - Synset('amazing.s.02')
# capital - Synset('capital.n.01')
# of - None
# France - Synset('france.n.01')
